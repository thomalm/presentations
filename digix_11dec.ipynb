# %% [markdown]
# ** Get Dependencies **

# %%
# Supress warnings
import warnings
warnings.filterwarnings('ignore')

import json
import random
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

from IPython.html.widgets import interact
from mpl_toolkits import mplot3d

# %% [markdown]
# # Introduction

# %% [markdown]
# In this presentation we will attempt to give you a short introduction to the field of <b>Machine Learning</b>. Machine learning is one of the fastest growing areas of computer science. We'll cover a bit of the background for machine learning, take you through the machine learning fundamentals and give some examples of real-world applications.
#
# Since many here probably never have heard of machine learning and are not programmers we'll focus on the giving you an intuition.
#
# > One should use common words to say uncommon things - Arthur Schopenhauer
#
# Starting off i will start by giving an introduction to the field of artificial intelligence, which machine learning is a subfield of. Artificial intelligence is defined as a field of study where one attempts to create computer software capable of intelligent behavior. To measure a softwares <b>intelligent behavior</b> a popular approach is to compare how well it compares to a humans. The field of artificial intelligence is wide reaching and is applied to anything from computer programs that play chess, understanding human language (both written and spoken), image recognication (where deep-learning is currently a hot subject) etc. So then, where do machine learning fit into all of this? Machine learning is about making algorithms revolving around the concept of learning. And the cool thing about machine learning is that it can be applied to all the *problems* listed above. It therefore very much mimics the way you and I learn to solve a problem - by teaching itself how to do so!
#
# ### Agenda
#
# * Introduction to Python & iPython
# * Machine Learning Fundamentals & Motivation
# * Building a Machine Learning Application
#
# # Python & Jupyter
#
# #### Background
#
# Python is a popular general purpose high-level programming language. Python first appeared back in 1991 and was created by Guido van Rossum. It's design principles highly emphasize code readability:
#
# > There should be one— and preferably only one— obvious way to do it.
#
# It is both a scripting and production ready language. Python supports multiple programming paradigms such as functional, object-oriented, procedural and imperative.
#
# #### TIOBE Index for September 2015
#
# <table style="float:left">
# <tr><td>Sep 2015<td>	Sep 2014<td>	Change<td>	Programming Language<td> Ratings	<td>Change</tr>
# <tr><td>1	<td>2	<td> <span style="color:green">&#9650;</span>	<td>Java	<td>19.565%	<td>+5.43%</tr>
# <tr><td>2	<td>1	<td><span style="color:red">&#9660;</span>	<td>C	<td>15.621%	<td>-1.10%</tr>
# <tr><td>3	<td>4	<td><span style="color:green">&#9650;</span>	<td>C++	<td>6.782%	<td>+2.11%</tr>
# <tr><td>4	<td>5	<td><span style="color:green">&#9650;</span>	<td>C#	<td>4.909%	<td>+0.56%</tr>
# <tr><td>5	<td>8	<td><span style="color:green">&#9650;</span>	<td>Python	<td>3.664%	<td>+0.88%</tr>
# </table>
#
# <br style="clear:both" />
#
# #### Jupyter / IPython Notebook
#
# The Jupyter Notebook is a web application that allows you to create and share documents that contain live code, equations, visualizations and explanatory text. It is a popular tool for data cleansing and transformation, numerical simulation, statistical modeling, machine learning and much more. For those who are interested in testing out Jupyter it already supports most programming languages.
#
# ##### Text
#
# <h1>Heading 1</h1>
# <h5>Heading 5</h5>
#
# "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."
#
# ##### Code

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ##### Mathematical Functions
#
# $J(\theta) = \frac{1}{m} \sum_{n=1}^{m} [-y^{(i)}log(h_{\theta}(x^{(i)}))-(1-y^{(i)})log(1-h_{\theta}(x^{(i)}))]$
#
# ##### Rich Media Content
#
# <img style="width:400px; float:left" src="http://journajobs.eu/wp-content/uploads/2015/09/Accenture-red-arrow-logo.png"/>
#
# <br clear="all"/>
#
# ##### And so much more...

# %% [markdown]
# ## The Python Scientific Stack
#
# > The SciPy Stack, a collection of open source software for scientific computing in Python, and particularly a specified set of core packages."
#
# We'll now give you a very short introduction to some of the most important packages.
#
# ### Numpy
#
# Numpy is the core library for scientific computing in Python. It provides a high-performance multidimensional array object, and tools for working with these arrays.

# %%
print ("Make a 3 row x 4 column array of random numbers")
x = np.random.random((3, 4))
print (x)
print()

print("Add 1 to every element")
x = x + 1
print (x)
print()

print("Get the element at row 1, column 2")
print (x[1, 2])
print()

# The colon syntax is called "slicing" the array. 
print ("Get the first row")
print (x[0, :])
print()

print("Get every 2nd column of the first row")
print (x[0, ::2])
print()
# Out:
# Make a 3 row x 4 column array of random numbers
# [[ 0.99266837  0.16664377  0.65650726  0.08238347]
#  [ 0.60707431  0.51410463  0.66419235  0.76930924]
#  [ 0.67637857  0.7429074   0.33518596  0.39850776]]
#
# Add 1 to every element
# [[ 1.99266837  1.16664377  1.65650726  1.08238347]
#  [ 1.60707431  1.51410463  1.66419235  1.76930924]
#  [ 1.67637857  1.7429074   1.33518596  1.39850776]]
#
# Get the element at row 1, column 2
# 1.66419235142
#
# Get the first row
# [ 1.99266837  1.16664377  1.65650726  1.08238347]
#
# Get every 2nd column of the first row
# [ 1.99266837  1.65650726]

# %%
print ("Max is", x.max())
print ("Min is", x.min())
print ("Mean is", x.mean())
# Out:
# Max is 1.99266837268
# Min is 1.08238346952
# Mean is 1.5504885899

# %% [markdown]
# Call the x.max function again, but use the axis keyword to print the maximum of each row in x.

# %%
print("Get the maximum of each row")
x.max(axis=1)
# Out:
# Get the maximum of each row
# array([ 1.99266837,  1.76930924,  1.7429074 ])

# %% [markdown]
# Here's a way to quickly simulate 500 coin "fair" coin tosses (where the probabily of getting Heads is 50%, or 0.5)

# %%
x = np.random.binomial(500, .5)
print ("number of heads:", x)

# Refresh this a few times
# Out:
# number of heads: 236

# %% [markdown]
# While it serves this purpose very well, its limitations become clear when we need more flexibility such as attaching labels to data, working with missing data, etc.

# %% [markdown]
# ### Pandas to the rescue
#
# At the very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels rather than simple integer indices. Pandas provides a host of useful tools, methods, and functionality on top of these data structures.

# %%
# Read the comma separated critics.csv file
critics = pd.read_csv('critics.csv')

# Let's drop rows with missing data
critics = critics[~critics.quote.isnull()]
critics = critics[critics.fresh != 'none']
critics = critics[critics.quote.str.len() > 0]

# %% [markdown]
# A quick sanity check that everything looks <b>ok</b> at this point

# %%
assert set(critics.columns) == set('critic date fresh imdb original_score publication '
                                   'quote review_date rt_id title'.split())
assert len(critics) > 10000

# %% [markdown]
# Display the first two rows of the dataset

# %%
critics.head(2)
# Out:
#             critic        date  fresh    imdb original_score    publication  \
# 0      Derek Adams  2009-10-04  fresh  114709            5/5       Time Out
# 1  Richard Corliss  2008-08-31  fresh  114709            NaN  TIME Magazine
#
#                                                quote  \
# 0  So ingenious in concept, design and execution ...
# 1                  The year's most inventive comedy.
#
#                                          review_date  rt_id      title
# 0  http://www.timeout.com/film/reviews/87745/toy-...   9559  Toy Story
# 1  http://www.time.com/time/magazine/article/0,91...   9559  Toy Story

# %% [markdown]
# How many reviews, critics, and movies are in this dataset?

# %%
n_reviews = len(critics)
n_movies = critics.rt_id.unique().size
n_critics = critics.critic.unique().size

print ("Number of reviews:", n_reviews)
print ("Number of critics:", n_critics)
print ("Number of movies:", n_movies)
# Out:
# Number of reviews: 15073
# Number of critics: 611
# Number of movies: 1872

# %% [markdown]
# ### Matplotlib / Seaborn
#
# Matplotlib is the single most used Python package for 2D-graphics. It provides both a very quick way to visualize data from Python and publication-quality figures in many formats. Seaborn provides an API on top of matplotlib which uses sane plot & color defaults, uses simple functions for common statistical plot types, and which integrates with the functionality provided by Pandas dataframes. Data visualization is a great tool for making data more interpretable.

# %%
# Array of 30 points from 0 to 10
x = np.linspace(0, 10, 30)
y = np.sin(x)

# Add noise
z = y + np.random.normal(size=30) * .2

plt.plot(x, y, 'ro-', label='A sine wave')
plt.plot(x, z, 'b-', label='Noisy sine')
plt.legend(loc = 'lower right')
plt.xlabel("X axis")
plt.ylabel("Y axis");

# %% [markdown]
# More advanced plot types. A **pair plot** will plot all pairwise relationships in a dataset. Note that the colors could easily be interchanged by using a different palette.

# %%
# Load the iris dataset
iris = seaborn.load_dataset("iris")

default_theme = ['deep', 'muted', 'pastel', 'bright', 'dark', 'colorblind']

# Generate a seaborn pairplot of the iris dataset
seaborn.pairplot(iris, hue='species', size=2.5, palette=default_theme[1]);

# %% [markdown]
# For more complex plots where your data has multiple attributes you can add an extra dimension to your plot or use various visual encodings to enchance your visualizations.

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)
# Calculate the size
s = z * 80
# Calculate color value
c = x + y

def plot_3D(elev=20, azim=40, marker = 'o'):
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.scatter(x, y, z, c=c, s=s, marker=marker, cmap='rainbow');
    ax.view_init(elev, azim)

interact(plot_3D, elev=[0, 90], azim=[0, 90], marker = [',', '+', '.', 'o', '*']);

# %% [markdown]
# ### Scikit-Learn
#
# Scikit-Learn is a Python package designed to give access to well-known machine learning algorithms within Python code, through a clean, well-thought-out API. It has been built by hundreds of contributors from around the world, and is used across industry and academia. Scikit-Learn is built upon NumPy and SciPy, which enable efficient in-core numerical and scientific computation within Python.
#
# #### Estimator objects
#
# Every algorithm is exposed in scikit-learn via an **Estimator** object. This means that every algorithm exposes more or less the same API, making it easy to experiment with different models. For instance polynomial regression is implemented as so:

# %%
from scipy.stats import logistic
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

model = make_pipeline(PolynomialFeatures(3), Ridge())

x = np.linspace(0, 600, 10)
y = logistic.cdf(x / 100) * 6000000

plt.plot(x, y, 'o');
plt.xlabel("Size in sqm")
plt.ylabel("Price");

# %% [markdown]
# #### Fitting the Model
#
# Lets fit our model $y = ax^3 + bx^2 + cx + d$

# %%
# Reshape X to a 2D array
X = x[:, np.newaxis]

# Fit the model
model.fit(X, y)

# Slope (x) and intercept (b) of the regression line y = ax + b
print("Powers:", model.steps[0][1].powers_.T,)
print()

X_fit = np.linspace(0, 600, 100)[:, np.newaxis]
print("Our newly generated test data")
print(X_fit.shape)
print()

y_fit = model.predict(X_fit)
print("Our model predictions")
print(y_fit.shape)
print()

print("Predict the price of a 100 sqm house")
print(np.around(model.predict(100), 2))

# Data
plt.plot(x, y, 'o', label='Data')
plt.plot(X_fit, y_fit, label='Regression line')
plt.legend(loc = 'lower right')
plt.xlabel("X axis")
plt.ylabel("Y axis");
# Out:
# Powers: [[0 1 2 3]]
#
# Our newly generated test data
# (100, 1)
#
# Our model predictions
# (100,)
#
# Predict the price of a 100 sqm house
# [ 4397967.93]

# %% [markdown]
# # What is Machine Learning?
#
# Many algorithms are today classified as “machine learning.” These algorithms share the goal of extracting information from data. All algorithms for analysis of data are designed to produce a useful summary of the data, from which decisions are made. However, algorithms called “machine learning” not only summarize our data; they are perceived as learning a model or classifier from the data, and thus discover something about data that will be seen in the future.
#
# > A computer program is said to learn from experience E with respect to some task T and some performance measure P, if its performance on T, as measured by P, improves with experience E. -- Tom Mitchell
#
# #### Short introduction, mention the background of the field and what tasks it is currently used to solve
#
#
#
# #### Try making the introduction more sellable. What can this be used for in Accenture?
#
# ##### Find some cool example cases or videos

# %% [markdown]
# # Building a Machine Learning Application
#
# There are a couple of "standard" steps involved in making a machine learning application. We will mainly focus on machine learning algorithms and evaluation as they are the most related to machine learning.
#
# In short, the steps are: **Collect, prepare, represent, model, reason**

# %% [markdown]
# ## Collect
#
# In order to extract information from data, you need data...
#
# ### Data Sources
#
# Data can come from many different sources:
#
# * APIs
# * Databases
# * Text files
# * Webpages
#
# Lets find some information about <a href="https://twitter.com/accenture">Accenture on Twitter!</a>

# %%
import tweepy

consumer_key = "XXX"
consumer_secret = "XXX"
access_token = "XXX"
access_token_secret = "XXX"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Get the Accenture account
accenture = api.get_user('Accenture')

print("Screen name:", accenture.screen_name)
print()

print("Number of followers:", accenture.followers_count)
print()

print("Number of tweets:", accenture.statuses_count)
# Out:
# Screen name: Accenture
#
# Number of followers: 287064
#
# Number of tweets: 14740

# %% [markdown]
# ... and in different **shapes**:
#
# * Structured Data
# * Unstructured data
#
# ... and in many different **formats**:
#
# * JSON
# * CSV
# * XML
# * ...

# %%
# Get the 5 latest tweet from the Accenture twitter account
timeline = api.user_timeline(screen_name='Accenture', count=5)

latest_tweet = timeline[0]

print(json.dumps(latest_tweet._json, indent=2))
# Out:
# {
#   "retweeted": false,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_screen_name": null,
#   "coordinates": null,
#   "contributors": null,
#   "favorite_count": 19,
#   "retweet_count": 15,
#   "is_quote_status": false,
#   "geo": null,
#   "truncated": false,
#   "id_str": "669742391260291076",
#   "created_at": "Thu Nov 26 05:00:03 +0000 2015",
#   "user": {
#     "profile_sidebar_border_color": "FFFFFF",
#     "description": "Follow us for updates on Accenture research, blogs, podcasts and more. Tweets by the Accenture Twitter Team.",
#     "listed_count": 4708,
#     "followers_count": 287064,
#     "profile_link_color": "003344",
#     "url": "http://t.co/NW2TnlESEG",
#     "has_extended_profile": false,
#     "profile_sidebar_fill_color": "AADDEE",
#     "name": "Accenture",
#     "profile_background_tile": false,
# ...

# %% [markdown]
# #### Munging Data
#
# The second part of the process is to munge or wrangle the data. This is the process of mapping data from a raw format into a more convenient one.

# %%
# Lets keep the user id, username, tweet text, date, retweet and favorite counts
fields = ['user_id', 'screen_name', 'text', 'created_at', 'retweet_count', 'favorite_count']

data = []

for tweet in timeline:
    story = []
    story.append(tweet._json["user"]["id"])
    story.append(tweet._json["user"]["name"])
    story.append(tweet._json["text"])
    story.append(tweet._json["created_at"])
    story.append(tweet._json["retweet_count"])
    story.append(tweet._json["favorite_count"])
    data.append(story)
    
df = pd.DataFrame(data)
df.columns = fields

df.head()
# Out:
#     user_id screen_name                                               text  \
# 0  10194682   Accenture  Screen-free interfaces could revolutionize the...
# 1  10194682   Accenture  With anti-money laundering professionals so cr...
# 2  10194682   Accenture  Will #DigitalDisruption help or harm the insur...
# 3  10194682   Accenture  Operating in real-time is not just an aspirati...
# 4  10194682   Accenture  4 ways #OilAndGas companies can focus their #d...
#
#                        created_at  retweet_count  favorite_count
# 0  Thu Nov 26 05:00:03 +0000 2015             15              19
# 1  Thu Nov 26 03:30:05 +0000 2015              5               6
# 2  Thu Nov 26 02:00:05 +0000 2015              3               2
# 3  Thu Nov 26 00:30:06 +0000 2015              5               4
# 4  Wed Nov 25 23:00:11 +0000 2015             15              14

# %% [markdown]
# ## Prepare
#
# In the preparation step we are mainly conserned with improve the data quality. If you wish to to create something useful you have to make sure that your data is **clean**.
#
# > garbage in, garbage out
#
# There are multiple reasons for why your data might be **dirty**. Every time humans are involved you will have some **dirty data**. This could e.g. stem from:
#
# * User entry errors
# * Different schemas
# * Legacy systems
# * Evolving applications
# * Programmer error
#
# It would therefore be wise measure **how dirty your data truly is**:
#
# * Validity - conforms to a schema / set of constraints
#     * Has all the required fields
#     * Cross-field contraints
#     * Range
#     * Datatype
#     * Regex
# * Accuracy - conforms a gold standard
#     * E.g. checking country names against an ISO dataset
# * Completeness **consider example with pandas.count()**
#     * Are some of the records missing?
# * Consistency
#     * Do you have contradicting information? (think two user tables with different address information)
#     * In that case, what data do you keep?
# * Uniformity
#     * Are your data types uniform?
#
# After you have audited your data you should create a data cleaning plan to "fix" your data:
#
# * Identify the causes and how to fix it
#
# Execute your plan and make the neccessary corrections.

# %% [markdown]
# ## Represent
#
# > Visualization is the process that transforms (abstract) data into interactive graphical representations for the purpose of exploration, confirmation, or presentation.
#
# ### Why use graphics to visualize data?
#
# * Figures are richer; provide more information with less clutter and in less space.
# * Figures provide the gestalt effect: they give an overview; make structure more visible.
# * Figures are more accessible, easier to understand, faster to grasp, more comprehensible, more memorable, more fun, and less formal.
#
# ### Anscombe's quartet
#
# Anscombe's quartet comprises four datasets that have nearly identical simple statistical properties, yet appear very different when graphed. Each dataset consists of eleven (x,y) points. They were constructed in 1973 by the statistician Francis Anscombe to demonstrate both the importance of graphing data before analyzing it and the effect of outliers on statistical properties.

# %%
from scipy.stats import linregress

x = [
    [10.0, 8.0,  13.0,  9.0,  11.0, 14.0, 6.0,  4.0,  12.0,  7.0,  5.0],
    [10.0, 8.0,  13.0,  9.0,  11.0, 14.0, 6.0,  4.0,  12.0,  7.0,  5.0],
    [10.0, 8.0,  13.0,  9.0,  11.0, 14.0, 6.0,  4.0,  12.0,  7.0,  5.0],
    [8.0,  8.0,  8.0,   8.0,  8.0,  8.0,  8.0,  19.0,  8.0,  8.0,  8.0]
]

y = [
    [8.04, 6.95, 7.58,  8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68],
    [9.14, 8.14, 8.74,  8.77, 9.26, 8.10, 6.13, 3.10, 9.13,  7.26, 4.74],
    [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15,  6.42, 5.73],
    [6.58, 5.76, 7.71,  8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
]

xmax, ymax = 20, 14

for i in range(4):
    ax1 = plt.subplot(2, 2, i+1)
    plt.scatter(x[i], y[i])
    slope, intercept, r_value, p_value, std_err = linregress(x[i], y[i])
    plt.plot([0, xmax], [intercept, slope * xmax + intercept])
    print("{0:.3f} {1:.2f} {2:.3f} {3:.3f} {4:.3f}".format(slope, intercept, r_value, p_value, std_err))
# Out:
# 0.500 3.00 0.816 0.002 0.118
# 0.500 3.00 0.816 0.002 0.118
# 0.500 3.00 0.816 0.002 0.118
# 0.500 3.00 0.817 0.002 0.118

# %% [markdown]
# When working with data visualization you often encounter the terms **exploratory** data analysis and **explanatory** data visualization. The first could be described as a conversation between you and your data, the latter a conversation between your data and your audience.
#
# # Data types:
#
# * Numeric (E.g. age expectancy)
# * Categorical (E.g. geographic region)
# * Time-series data
#
# #### Time-series

# %%
from numpy.random import randn

# Plot time-series plot, e.g. page views on a website
df = pd.DataFrame(randn(365, 3),
                  index=pd.date_range('1/1/2014', periods=365),
                  columns=['mylearning', 'myscheduling', 'myte'])
df = df.cumsum()

df.plot();

# %% [markdown]
# #### Maps

# %%
from IPython.display import IFrame
IFrame('http://localhost:8000/', width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="http://localhost:8000/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Visual Encodings
#
# Visual encodings are a mapping from data to display elements. Visual encondings ranked by effectivness:
#
# * Position
# * Length
# * Orientation
# * Size
# * Volume
# * Color
#
# ### A Few Examples

# %%
# %run visual_encodings.py

# %% [markdown]
# ## Model
#
# Selecting the right tool for the task is essential. This section will guide you through a few typical machine learning problems and how different methods can help you solve them.
#
# ## Supervised Learning: Regression and Classification
#
# In Supervised Learning, we have a dataset consisting of both features and labels. The task is to construct an estimator which is able to predict the label of an object given the set of features.
#
# > Would like to do prediction: estimate a function f(x) so that y = f(x)
#
# Where y can be:
# - Real number (regression)
# - Categorical (classification)
# - Complex object (Ranking of objects, Parse tree, etc.)
#
# Supervised learning can be broken down into two categories, <b>classification</b> and <b>regression</b>. In classification, the label is discrete, while in regression, the label is continuous. For example classifying if an email is spam or not is a classification problem: the label is from two categories (spam and not spam). We might wish to estimate housing prices: this would be a regression problem, because the label **price** is a continuous quantity.

# %% [markdown]
# ### Regression
#
# One of the simplest examples of regression is fitting a straight line to the data.

# %%
from sklearn.linear_model import LinearRegression

# Generate test data
np.random.seed(0)
X = np.random.random(size=(20, 1))
y = 3 * X.squeeze() + 2 + np.random.randn(20)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Generate predictions
X_fit = np.linspace(0, 1, 100)[:, np.newaxis]
y_fit = model.predict(X_fit)

# Data
plt.plot(X.squeeze(), y, 'o')
# Regression line
plt.plot(X_fit.squeeze(), y_fit);

# %% [markdown]
# Scikit-learn also has some more sophisticated models, which can respond to finer features in the data:

# %%
from sklearn.ensemble import RandomForestRegressor

# Fit a random forest regression model
model = RandomForestRegressor()
model.fit(X, y)

X_fit = np.linspace(0, 1, 100)[:, np.newaxis]
y_fit = model.predict(X_fit)

plt.plot(X.squeeze(), y, 'o')
plt.plot(X_fit.squeeze(), y_fit);

# %% [markdown]
# #### Classification
#
# There are many supervised learning algorithms available; here we'll introduce one of the most powerful and interesting methods: Support Vector Machines (SVMs).

# %%
from sklearn.datasets.samples_generator import make_blobs

# Generate isotropic Gaussian blobs for clustering
X, y = make_blobs(n_samples=100, centers=2, random_state=0, cluster_std=0.55)

# Plot the data, the label determines the color
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');

# %% [markdown]
# A discriminative classifier attempts to draw a line between the two sets of data. However, it is possible to come up with a large set of lines that separate the clusters successfully. Which of the following lines is the **best** one?

# %%
# Plot the data
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')

# Our endpoints
xfit = np.linspace(-1, 3.5)

# Three lines that successfully separate the data
for a, b in [(1.0, 1.1), (0.3, 2.1), (-0.2, 2.8)]:
    #Plot the line y = ax + b
    plt.plot(xfit, a * xfit + b, '-k')

# Limit the x-axis
plt.xlim(-1, 3.5);

# %% [markdown]
# Lets take a look at the line produced by a Support Vector Classifier

# %%
from sklearn.svm import SVC

kernel = ['linear', 'poly', 'rbf']

# Initialize the SVC classifier
clf = SVC(kernel='linear')

def plot_svc_decision_function(clf, ax=None):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=150, facecolors='none', zorder=10)
    x = np.linspace(plt.xlim()[0], plt.xlim()[1], 30)
    y = np.linspace(plt.ylim()[0], plt.ylim()[1], 30)
    Y, X = np.meshgrid(y, x)
    P = np.zeros_like(X)
    for i, xi in enumerate(x):
        for j, yj in enumerate(y):
            P[i, j] = clf.decision_function([xi, yj])
    # plot the margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
# Fit the SVC classifier
clf.fit(X, y)

# Generate test data
X_test = np.linspace(-1, 3.5, 50)[:, None]

# Plot data
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')

# Plot SVC decision boundary
plot_svc_decision_function(clf);

# %% [markdown]
# ### Kernels
#
# Where SVM gets incredibly exciting is when it is used in conjunction with kernels. For the following example it is not possible to linearly separate the data.

# %%
from sklearn.datasets.samples_generator import make_circles

X, y = make_circles(200, factor=.2, noise=.1)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');

# %% [markdown]
# One way we can adjust this is to apply a kernel, which is some functional transformation of the input data. For example, one simple model we could use is a **radial basis function**

# %%
r = np.exp(-(X[:, 0] ** 2 + X[:, 1] ** 2))

# %% [markdown]
# When applied to the data we see the following effect

# %%
def plot_3D(elev=30, azim=30):
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=50, cmap='rainbow')
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('r')

interact(plot_3D, elev=[0, 90], azip=(0, 180));

# %% [markdown]
# We can see that with this additional dimension, the data becomes trivially linearly separable. The use radial basis function as a kernel simply type kernel='rbf'.

# %%
clf = SVC(kernel='rbf').fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')
plot_svc_decision_function(clf);

# %% [markdown]
# #### Polynomial kernel

# %%
X, y = make_blobs(n_samples=100, centers=2, random_state=0, cluster_std=1.1, shuffle=False)

clf = SVC(kernel='poly').fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');
plot_svc_decision_function(clf);

# %% [markdown]
# #### Multi-class Problem

# %%
def plot_multi_class(kernel='linear', centers=4):
    X, y = make_blobs(n_samples=100, centers=centers, random_state=0, cluster_std=0.5)
    clf = SVC(kernel=kernel).fit(X, y)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, 0.02))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap='rainbow', alpha=0.2)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
interact(plot_multi_class, kernel=['linear', 'poly', 'rbf'], centers=[2, 10])
# Out:
# <function __main__.plot_multi_class>

# %% [markdown]
# ### Unsupervised Learning: Dimensionality Reduction and Clustering
#
# In machine learning, the problem of unsupervised learning is that of trying to find hidden structure in unlabeled data. Since the examples given to the learner are unlabeled, there is no error or reward signal to evaluate a potential solution. This distinguishes unsupervised learning from supervised learning

# %% [markdown]
# #### Clustering
#
# > Clustering is the process of examining a collection of “points,” and grouping
# the points into “clusters” according to some distance measure.
#
# The goal is that points in the same cluster have a small distance from one another, while points in different clusters are at a large distance from one another. In this section we will take a look at K-Means Clustering. K Means is an algorithm for unsupervised clustering: that is, finding clusters in data based on the data attributes alone (not the labels).
#
# Market segmentation is a typical clustering problem. Every marketing offering will not be right for every customer. Segmentation is a way of organizing your customers into groups with similar traits, product preferences or expectations. Once the segments are identified, marketing messages and products can be customized for each segments.

# %%
from sklearn.datasets.samples_generator import make_blobs

# Generate clusters
X, y = make_blobs(n_samples=300, centers=5, random_state=1, cluster_std=0.90)

# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], s=50);
plt.xlabel("Age")
plt.ylabel("Income");

# %% [markdown]
# You can probably see from the data that we have five different clusters. Lets implement K-Means and see the result when varying the number of predifined clusters.

# %%
from sklearn.cluster import KMeans

def plot_clusters(num_clusters=2):
    # KMeans with 4 Clusters
    k_means = KMeans(num_clusters)
    # Fit the model on the attributes
    k_means.fit(X)
    # Predict the labels for each point
    y_pred = k_means.predict(X)
    # Get the cluster centers
    mu = k_means.cluster_centers_
    # Plot the result
    plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=50, cmap='rainbow', alpha=0.4);
    plt.scatter(mu[:, 0], mu[:, 1], s=200, c=np.unique(y_pred), cmap='rainbow')
    print("Cluster Centers")
    print(mu)

interact(plot_clusters, num_clusters=[1, 10]);
# Out:
# Cluster Centers
# [[-9.80087983 -3.97148486]
#  [-1.62725717  4.48955683]
#  [-6.22074264 -2.89531205]
#  [-7.01671969 -8.16207374]
#  [-2.06028394  0.88197379]]

# %% [markdown]
# ## Reason: Validation and Model Selection
#
# One of the most important pieces of machine learning is <b>model validation</b>: that is checking how well your model performs or fits a particular dataset. We will focus on the latter, which is often referred to as **offline validation**. **Online validation** refers to online experiments designed to measure the true performance of your model such as e.g. **A/B-testing**
#
# ### Validation Sets
#
# To assess how well our model performs we cannot test our model on the same data that was used for training. <b>This is generally not a good idea</b>. If we optimize our estimator this way, we will tend to over-fit the data: that is, we learn the noise.
#
# #### Hold-Out Dataset
#
# A better way to test a model is to use a hold-out set which doesnt enter the training.

# %%
from sklearn.datasets import load_digits
from sklearn.cross_validation import train_test_split

# Load the digits dataset
digits = load_digits()

# Extract the features and labels
X, y = digits.data, digits.target

# Generate a 75:25 hold-out dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train.shape, X_test.shape
# Out:
# ((1347, 64), (450, 64))

# %% [markdown]
# We can now use classifier to predict the labels for our hold-out dataset

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=10)

# Fit the KNN model
knn.fit(X_train, y_train)

# Predict labels for our hold-out dataset
y_pred = knn.predict(X_test)

# Calculate the accuracy by checking the results against our hold-out dataset labels
print("{0} / {1} correct".format(np.sum(y_test == y_pred), len(y_test)))
# Out:
# 440 / 450 correct

# %% [markdown]
# A confusion matrix can give us more information about our models performance. More spesifically how well our model is at predicting the differnet label values

# %%
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.imshow(cm, cmap='Blues', interpolation='nearest')
plt.colorbar()
plt.grid(False)
plt.ylabel('True')
plt.xlabel('Predicted');

# %% [markdown]
# The accuracy can also be computed directly from the <b>model.score</b> method. Using this method we can quickly see how different model parameters perform. I would also like to mention <b>grid-search</b> here, which can be used to search for the optimal parameters using different heuristics.

# %%
# For all our model parameters
for n_neighbors in [1, 3, 5, 10, 20, 30]:
    # Initialize a model with the given parameter
    knn = KNeighborsClassifier(n_neighbors)
    # Fit the model
    knn.fit(X_train, y_train)
    # Output the model score
    print(n_neighbors, knn.score(X_test, y_test))
# Out:
# 1 0.984444444444
# 3 0.984444444444
# 5 0.982222222222
# 10 0.98
# 20 0.964444444444
# 30 0.966666666667

# %% [markdown]
# Increasing the number of neighbours could have huge impacts on the training time on a real dataset. If performance is of importance testing the running time might be a good idea.

# %%
knn = KNeighborsClassifier(1)
# %timeit knn.fit(X_train, y_train)
# Out:
# 1000 loops, best of 3: 1.89 ms per loop

# %% [markdown]
# #### Cross-Validation
#
# One of the main problems with validation sets is that you "lose" some of the data. Above we only used 75% of the data for training and 25% for validation. Another option is to use K-fold cross-validation where you split the data into K chunks and perform K fits, where each chunk gets a turn as the validation set.

# %%
from sklearn.cross_validation import cross_val_score

#Perform 10-fold cross validation on KNN classifier with n_neighbors = 1
cv = cross_val_score(KNeighborsClassifier(1), X, y, cv=10)

# Mean model score
cv.mean()
# Out:
# 0.97614938602520218

# %% [markdown]
# This will give us an even better idea of how well our model is doing. The choice of **evaluation metrics** used, in this case will vary from problem to problem. Classification, regression and other problems such as evaluating the quality of a ranked list will require different evaluation metrics

# %% [markdown]
# ### Overfitting, Underfitting and Model Selection
#
# The issues associated with validation and cross-validation are some of the most important aspects of machine learning. Selecting the optimal model for your data is **vital**.
#
# #### Illusatration of Bias-Variance Tradeoff

# %%
def test_func(x, err=0.5):
    y = 10 - 1. / (x + 0.1)
    if err > 0:
        y = np.random.normal(y, err)
    return y

def make_data(N=40, error=1.0, random_seed=1):
    # randomly sample the data
    np.random.seed(1)
    X = np.random.random(N)[:, np.newaxis]
    y = test_func(X.ravel(), error)
    return X, y

X, y = make_data(40, error=1)
plt.scatter(X.ravel(), y);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_test = np.linspace(-0.1, 1.1, 500)[:, None]

model = LinearRegression()
model.fit(X, y)
y_test = model.predict(X_test)

plt.scatter(X, y)
plt.plot(X_test.ravel(), y_test)
plt.title("mean squared error: {0:.3g}".format(mean_squared_error(model.predict(X), y)));

# %% [markdown]
# We have a straight line to the data, but clearly this model is not the best choice. We can say that this model is <b>biased</b> and <b>under-fits</b> the data.
#
# Lets try to improve our results by creating a mode complicated model.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

def PolynomialRegression(degree=2, **kwargs):
    return make_pipeline(PolynomialFeatures(degree),
                         LinearRegression(**kwargs))

model = PolynomialRegression(2)
model.fit(X, y)
y_test = model.predict(X_test)

plt.scatter(X, y)
plt.plot(X_test.ravel(), y_test)
plt.title("mean squared error: {0:.3g}".format(mean_squared_error(model.predict(X), y)));

# %% [markdown]
# As you can see this reduced the square error, and makes a much better fit. What happens if we use an even more complex model? By plotting the **true y** which we wish to estimate, we see that the model learn the noise.

# %%
def plot_SVM(r=20, plot_y=False):
    model = PolynomialRegression(r)
    model.fit(X, y)
    y_test = model.predict(X_test)
    plt.scatter(X.ravel(), y)
    plt.plot(X_test.ravel(), y_test)
    plt.title("mean squared error: {0:.3g}".format(mean_squared_error(model.predict(X), y)))
    plt.ylim(-4, 14)
    plt.plot(X_test.ravel(), y_test);
    if plot_y:
        plot_true_y()
    
def plot_true_y():
    x = np.arange(0, 1, 0.02);
    # The real y function
    y = 10 - 1. / (x + 0.1)
    plt.plot(x, y, '--')

interact(plot_SVM, r=[1, 100], plot_y=False);

# %% [markdown]
# When we increase the degree to this extend, it is clear that the result no longer reflect the underlying distribution, but is more sensitive to the noise in the training data. For this reason, we call it a <b>high-variance model</b>, and we say that it <b>over-fits</b> the data.

# %% [markdown]
# ### References
